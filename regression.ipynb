# %%
#Libraries importation

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Data importation
data=pd.read_csv('data/data.csv')

#show columns
print(data.columns)

#show data
print(data)

# plot scatter plot of temperature vs. rendement
plt.scatter(data.temperature,data.rendement)

# %%
#loss_function : loss is a number indicating how bad the model's prediction was on a single example.
# mean squar error

def loss_function(m, b, points):
    total_error = 0
    for i in range(len(points)):
        x = points.iloc[i].temperature
        y = points.iloc[i].rendement
        total_error += (y - (m * x + b))**2
    total_error /= float(len(points))
    return total_error

# %%
# gradient_descent :

def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0
    b_gradient = 0

    n = len(points)
    for i in range(n):
        x = points.iloc[i].temperature
        y = points.iloc[i].rendement

        m_gradient += -(2/n) * x * (y - (m_now * x + b_now))
        b_gradient += -(2/n) * (y - (m_now * x + b_now))

    m = m_now - m_gradient * L
    b = b_now - b_gradient * L

    return m, b

# %%
m=0
b=0
L=0.0001
epochs =1000
error[]
for i in range(epochs):
    if i%50==0:
        print(f"Epoch:{i}")

        m,b=gradient_descent(m,b,data,L)
        error.append90
        print(m,b)

        plt.scatter(data.temperature,data.rendement,color="black")
        plt.plot(list(range(100,200)),[m*x+b for x in range(100,200)],color="red")
        plt.show()
# Out:
# Epoch:0
# 2.0314 0.013460000000000003
# Epoch:50
# -4.814808340000001 -0.031993292000000007
# Epoch:100
# 18.258231911268005 0.12110254851840008
# Epoch:150
# -59.50235351488022 -0.3949503974180759
# Epoch:200
# 202.56578490667152 1.3441568445929346
# Epoch:250
# -680.6542756839763 -4.517059749069459
# Epoch:300
# 2295.967303787723 15.236277657715666
# Epoch:350
# -7735.820265816702 -51.336361407659844
# Epoch:400
# 26073.234450283107 173.02615357330612
# Epoch:450
# -87869.7864559077 -583.1187907156187
# Epoch:500
# 296140.12220133975 1965.235100263848
# Epoch:550
# -998047.1722364223 -6623.208030595057
# Epoch:600
# 3363613.074869631 22321.49806586731
# Epoch:650
# -11336021.354354564 -75227.73194496517
# Epoch:700
# 38204575.5998013 253531.94633770626
# Epoch:750
# -128756770.1663742 -854451.4389857991
# Epoch:800
# 433935096.58381164 2879665.7995868498
# Epoch:850
# -1462444783.7642336 -9705027.921043608
# Epoch:900
# 4928720369.126577 32707811.827163387
# Epoch:950
# -16610736168.468153 -110231620.4264128
